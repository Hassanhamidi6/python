# %%
d={
    1:2,
    2:3
}
d
# Out:
# {1: 2, 2: 3}

# %%
import cv2

# %%
img=cv2.imread("Screenshot 2025-01-11 233934.png")

# %%
import matplotlib.pyplot as plt
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1173.5), np.float64(1490.5), np.float64(-0.5))

# %%
img
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]],
#       shape=(1491, 1174), dtype=uint8)
